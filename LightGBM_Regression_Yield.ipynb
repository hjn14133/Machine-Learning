# %% [markdown]
# <a href="https://colab.research.google.com/github/hjn14133/Machine-Learning/blob/main/LightGBM_Regression_Yield.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_absolute_error
import lightgbm as lgb
import pprint
RANDOM_STATE = 42
# Importing the dataset
df = pd.read_csv("FT_join_JH_cleaned.csv")

#Select columns
X = df[['DISTANCE', 'Heading','Elevation', 'AppliedRat']]
y = df['VRYIELDBAL']

# Splitting the dataset into the training set and test set
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = RANDOM_STATE)

# Feature scaling
sc = StandardScaler()
x_train = sc.fit_transform(x_train)
x_test = sc.transform(x_test)

# %%
#Set the minimum error arbitrarily large
min = 99999999999999999999999 
count = 0 #Used for keeping track of the iteration number
#How many runs to perform using randomly selected hyperparameters
iterations = 50
for i in range(iterations):
    print('iteration number', count)
    count += 1 #increment count
    try:
        d_train = lgb.Dataset(x_train, label=y_train) #Load in data
        params = {} #initialize parameters
        params['learning_rate'] = np.random.uniform(0, 1)
        params['boosting_type'] = np.random.choice(['gbdt', 'dart', 'goss'])
        params['objective'] = 'regression'
        params['metric'] = 'mae'
        params['sub_feature'] = np.random.uniform(0, 1)
        params['num_leaves'] = np.random.randint(20, 300)
        params['min_data'] = np.random.randint(10, 100)
        params['max_depth'] = np.random.randint(5, 200)
        iterations = np.random.randint(10, 10000)
        print(params, iterations)
    #Train using selected parameters
        clf = lgb.train(params, d_train, iterations)
        y_pred=clf.predict(x_test) #Create predictions on test setmae=mean_absolute_error(y_pred,y_test)
        print('MAE:', mae)
        if mae < min:
            min = mae
            pp = params 
    except: #in case something goes wrong
        print('failed with')
        print(params)
print("*" * 50)
print('Minimum is: ', min)
print('Used params', pp)
# Out:
# iteration number 0
# {'learning_rate': 0.5527163460989927, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.43068589000587354, 'num_leaves': 241, 'min_data': 72, 'max_depth': 158} 7269
# failed with
# {'learning_rate': 0.5527163460989927, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.43068589000587354, 'num_leaves': 241, 'min_data': 72, 'max_depth': 158}
# iteration number 1
# {'learning_rate': 0.5266356738306156, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.8053201797011244, 'num_leaves': 231, 'min_data': 44, 'max_depth': 6} 6418
# failed with
# {'learning_rate': 0.5266356738306156, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.8053201797011244, 'num_leaves': 231, 'min_data': 44, 'max_depth': 6}
# iteration number 2
# {'learning_rate': 0.3442285774652576, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.06506152268249832, 'num_leaves': 148, 'min_data': 80, 'max_depth': 174} 7229
# failed with
# {'learning_rate': 0.3442285774652576, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.06506152268249832, 'num_leaves': 148, 'min_data': 80, 'max_depth': 174}
# iteration number 3
# {'learning_rate': 0.1607452776018482, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.43974752418849683, 'num_leaves': 266, 'min_data': 55, 'max_depth': 156} 7212
# failed with
# {'learning_rate': 0.1607452776018482, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.43974752418849683, 'num_leaves': 266, 'min_data': 55, 'max_depth': 156}
# iteration number 4
# {'learning_rate': 0.03150382074006919, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.08157786251138988, 'num_leaves': 185, 'min_data': 46, 'max_depth': 152} 3931
# failed with
# {'learning_rate': 0.03150382074006919, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.08157786251138988, 'num_leaves': 185, 'min_data': 46, 'max_depth': 152}
# iteration number 5
# {'learning_rate': 0.8675102836308216, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.3810437377210548, 'num_leaves': 126, 'min_data': 23, 'max_depth': 187} 9365
# failed with
# {'learning_rate': 0.8675102836308216, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.3810437377210548, 'num_leaves': 126, 'min_data': 23, 'max_depth': 187}
# iteration number 6
# {'learning_rate': 0.912933980488954, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.47025978631314114, 'num_leaves': 61, 'min_data': 70, 'max_depth': 124} 1236
# failed with
# {'learning_rate': 0.912933980488954, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.47025978631314114, 'num_leaves': 61, 'min_data': 70, 'max_depth': 124}
# iteration number 7
# {'learning_rate': 0.9949667325137608, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.20187086548009536, 'num_leaves': 295, 'min_data': 55, 'max_depth': 108} 5411
# failed with
# {'learning_rate': 0.9949667325137608, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.20187086548009536, 'num_leaves': 295, 'min_data': 55, 'max_depth': 108}
# iteration number 8
# {'learning_rate': 0.40630583132060893, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.03936690821671518, 'num_leaves': 105, 'min_data': 71, 'max_depth': 85} 2205
# failed with
# {'learning_rate': 0.40630583132060893, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.03936690821671518, 'num_leaves': 105, 'min_data': 71, 'max_depth': 85}
# iteration number 9
# {'learning_rate': 0.36249156574576025, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.1232792047703104, 'num_leaves': 164, 'min_data': 26, 'max_depth': 89} 1251
# failed with
# {'learning_rate': 0.36249156574576025, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.1232792047703104, 'num_leaves': 164, 'min_data': 26, 'max_depth': 89}
# iteration number 10
# {'learning_rate': 0.35679726812250834, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.18029246725380899, 'num_leaves': 69, 'min_data': 21, 'max_depth': 161} 1861
# failed with
# {'learning_rate': 0.35679726812250834, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.18029246725380899, 'num_leaves': 69, 'min_data': 21, 'max_depth': 161}
# iteration number 11
# {'learning_rate': 0.28641682910967314, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.6898960898277993, 'num_leaves': 129, 'min_data': 18, 'max_depth': 164} 8769
# failed with
# {'learning_rate': 0.28641682910967314, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.6898960898277993, 'num_leaves': 129, 'min_data': 18, 'max_depth': 164}
# iteration number 12
# {'learning_rate': 0.837746405357314, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.21396023223387683, 'num_leaves': 113, 'min_data': 40, 'max_depth': 87} 4130
# failed with
# {'learning_rate': 0.837746405357314, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.21396023223387683, 'num_leaves': 113, 'min_data': 40, 'max_depth': 87}
# iteration number 13
# {'learning_rate': 0.2438162488745147, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.670364520824443, 'num_leaves': 86, 'min_data': 97, 'max_depth': 65} 9847
# failed with
# {'learning_rate': 0.2438162488745147, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.670364520824443, 'num_leaves': 86, 'min_data': 97, 'max_depth': 65}
# iteration number 14
# {'learning_rate': 0.13479746532740655, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.6387240646736375, 'num_leaves': 176, 'min_data': 70, 'max_depth': 60} 5325
# failed with
# {'learning_rate': 0.13479746532740655, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.6387240646736375, 'num_leaves': 176, 'min_data': 70, 'max_depth': 60}
# iteration number 15
# {'learning_rate': 0.11101281095457871, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.2896082932777002, 'num_leaves': 261, 'min_data': 89, 'max_depth': 124} 1659
# failed with
# {'learning_rate': 0.11101281095457871, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.2896082932777002, 'num_leaves': 261, 'min_data': 89, 'max_depth': 124}
# iteration number 16
# {'learning_rate': 0.09634892149960583, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7267639191974286, 'num_leaves': 227, 'min_data': 64, 'max_depth': 158} 5475
# failed with
# {'learning_rate': 0.09634892149960583, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7267639191974286, 'num_leaves': 227, 'min_data': 64, 'max_depth': 158}
# iteration number 17
# {'learning_rate': 0.7355416513131826, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5821405766894702, 'num_leaves': 85, 'min_data': 84, 'max_depth': 116} 3093
# failed with
# {'learning_rate': 0.7355416513131826, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5821405766894702, 'num_leaves': 85, 'min_data': 84, 'max_depth': 116}
# iteration number 18
# {'learning_rate': 0.6132188145958395, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7561756974526709, 'num_leaves': 53, 'min_data': 76, 'max_depth': 158} 4230
# failed with
# {'learning_rate': 0.6132188145958395, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7561756974526709, 'num_leaves': 53, 'min_data': 76, 'max_depth': 158}
# iteration number 19
# {'learning_rate': 0.7383753980217961, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9968643018130993, 'num_leaves': 242, 'min_data': 20, 'max_depth': 137} 6261
# failed with
# {'learning_rate': 0.7383753980217961, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9968643018130993, 'num_leaves': 242, 'min_data': 20, 'max_depth': 137}
# iteration number 20
# {'learning_rate': 0.381876107438774, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.017503760683684533, 'num_leaves': 185, 'min_data': 32, 'max_depth': 162} 350
# failed with
# {'learning_rate': 0.381876107438774, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.017503760683684533, 'num_leaves': 185, 'min_data': 32, 'max_depth': 162}
# iteration number 21
# {'learning_rate': 0.6256588655097566, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.053110430383816465, 'num_leaves': 281, 'min_data': 61, 'max_depth': 25} 9619
# failed with
# {'learning_rate': 0.6256588655097566, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.053110430383816465, 'num_leaves': 281, 'min_data': 61, 'max_depth': 25}
# iteration number 22
# {'learning_rate': 0.4482636618401895, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9169199269324514, 'num_leaves': 55, 'min_data': 36, 'max_depth': 161} 5468
# failed with
# {'learning_rate': 0.4482636618401895, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9169199269324514, 'num_leaves': 55, 'min_data': 36, 'max_depth': 161}
# iteration number 23
# {'learning_rate': 0.8983887383083655, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5138665414099177, 'num_leaves': 247, 'min_data': 19, 'max_depth': 125} 6978
# failed with
# {'learning_rate': 0.8983887383083655, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5138665414099177, 'num_leaves': 247, 'min_data': 19, 'max_depth': 125}
# iteration number 24
# {'learning_rate': 0.6054678530286005, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.21930440343284763, 'num_leaves': 237, 'min_data': 33, 'max_depth': 130} 6456
# failed with
# {'learning_rate': 0.6054678530286005, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.21930440343284763, 'num_leaves': 237, 'min_data': 33, 'max_depth': 130}
# iteration number 25
# {'learning_rate': 0.5926335789458791, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.06484727337157181, 'num_leaves': 222, 'min_data': 49, 'max_depth': 69} 1612
# failed with
# {'learning_rate': 0.5926335789458791, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.06484727337157181, 'num_leaves': 222, 'min_data': 49, 'max_depth': 69}
# iteration number 26
# {'learning_rate': 0.2506961361632226, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.686353378603661, 'num_leaves': 87, 'min_data': 83, 'max_depth': 81} 1765
# failed with
# {'learning_rate': 0.2506961361632226, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.686353378603661, 'num_leaves': 87, 'min_data': 83, 'max_depth': 81}
# iteration number 27
# {'learning_rate': 0.37850023918166287, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.40000556507015894, 'num_leaves': 150, 'min_data': 90, 'max_depth': 15} 6876
# failed with
# {'learning_rate': 0.37850023918166287, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.40000556507015894, 'num_leaves': 150, 'min_data': 90, 'max_depth': 15}
# iteration number 28
# {'learning_rate': 0.6248065447517026, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.868725476788072, 'num_leaves': 43, 'min_data': 21, 'max_depth': 156} 4563
# failed with
# {'learning_rate': 0.6248065447517026, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.868725476788072, 'num_leaves': 43, 'min_data': 21, 'max_depth': 156}
# iteration number 29
# {'learning_rate': 0.9875697910370337, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.1939129050759023, 'num_leaves': 228, 'min_data': 54, 'max_depth': 123} 1819
# failed with
# {'learning_rate': 0.9875697910370337, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.1939129050759023, 'num_leaves': 228, 'min_data': 54, 'max_depth': 123}
# iteration number 30
# {'learning_rate': 0.19512691156598294, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.20154254860845278, 'num_leaves': 74, 'min_data': 60, 'max_depth': 121} 6249
# failed with
# {'learning_rate': 0.19512691156598294, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.20154254860845278, 'num_leaves': 74, 'min_data': 60, 'max_depth': 121}
# iteration number 31
# {'learning_rate': 0.9441377846345933, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.44383612808345185, 'num_leaves': 44, 'min_data': 82, 'max_depth': 20} 5796
# failed with
# {'learning_rate': 0.9441377846345933, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.44383612808345185, 'num_leaves': 44, 'min_data': 82, 'max_depth': 20}
# iteration number 32
# {'learning_rate': 0.7563249063951046, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.765762510941717, 'num_leaves': 165, 'min_data': 46, 'max_depth': 91} 659
# failed with
# {'learning_rate': 0.7563249063951046, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.765762510941717, 'num_leaves': 165, 'min_data': 46, 'max_depth': 91}
# iteration number 33
# {'learning_rate': 0.4055772858071257, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9858115411921332, 'num_leaves': 123, 'min_data': 96, 'max_depth': 133} 1067
# failed with
# {'learning_rate': 0.4055772858071257, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9858115411921332, 'num_leaves': 123, 'min_data': 96, 'max_depth': 133}
# iteration number 34
# {'learning_rate': 0.3258211945506917, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.40301859661944894, 'num_leaves': 86, 'min_data': 43, 'max_depth': 94} 508
# failed with
# {'learning_rate': 0.3258211945506917, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.40301859661944894, 'num_leaves': 86, 'min_data': 43, 'max_depth': 94}
# iteration number 35
# {'learning_rate': 0.9871780781035869, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.43672557711989257, 'num_leaves': 281, 'min_data': 70, 'max_depth': 77} 1067
# failed with
# {'learning_rate': 0.9871780781035869, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.43672557711989257, 'num_leaves': 281, 'min_data': 70, 'max_depth': 77}
# iteration number 36
# {'learning_rate': 0.31802097728990086, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.3924597342011883, 'num_leaves': 66, 'min_data': 98, 'max_depth': 186} 3266
# failed with
# {'learning_rate': 0.31802097728990086, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.3924597342011883, 'num_leaves': 66, 'min_data': 98, 'max_depth': 186}
# iteration number 37
# {'learning_rate': 0.7878549618573463, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.943464638282591, 'num_leaves': 299, 'min_data': 62, 'max_depth': 26} 3028
# failed with
# {'learning_rate': 0.7878549618573463, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.943464638282591, 'num_leaves': 299, 'min_data': 62, 'max_depth': 26}
# iteration number 38
# {'learning_rate': 0.21616554537026156, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.3539651955677102, 'num_leaves': 272, 'min_data': 48, 'max_depth': 19} 3206
# failed with
# {'learning_rate': 0.21616554537026156, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.3539651955677102, 'num_leaves': 272, 'min_data': 48, 'max_depth': 19}
# iteration number 39
# {'learning_rate': 0.4828314362104157, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.6328004966632886, 'num_leaves': 83, 'min_data': 50, 'max_depth': 120} 4187
# failed with
# {'learning_rate': 0.4828314362104157, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.6328004966632886, 'num_leaves': 83, 'min_data': 50, 'max_depth': 120}
# iteration number 40
# {'learning_rate': 0.9831765457959475, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.47910119454327105, 'num_leaves': 77, 'min_data': 19, 'max_depth': 171} 9068
# failed with
# {'learning_rate': 0.9831765457959475, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.47910119454327105, 'num_leaves': 77, 'min_data': 19, 'max_depth': 171}
# iteration number 41
# {'learning_rate': 0.43192315976674067, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5734640110648194, 'num_leaves': 140, 'min_data': 35, 'max_depth': 86} 775
# failed with
# {'learning_rate': 0.43192315976674067, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5734640110648194, 'num_leaves': 140, 'min_data': 35, 'max_depth': 86}
# iteration number 42
# {'learning_rate': 0.5501550504015496, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.34259814132777866, 'num_leaves': 46, 'min_data': 37, 'max_depth': 45} 3305
# failed with
# {'learning_rate': 0.5501550504015496, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.34259814132777866, 'num_leaves': 46, 'min_data': 37, 'max_depth': 45}
# iteration number 43
# {'learning_rate': 0.6731135766294323, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.20363856268595337, 'num_leaves': 70, 'min_data': 69, 'max_depth': 193} 4029
# failed with
# {'learning_rate': 0.6731135766294323, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.20363856268595337, 'num_leaves': 70, 'min_data': 69, 'max_depth': 193}
# iteration number 44
# {'learning_rate': 0.6727088209972387, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9457763341278923, 'num_leaves': 203, 'min_data': 16, 'max_depth': 150} 8017
# failed with
# {'learning_rate': 0.6727088209972387, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.9457763341278923, 'num_leaves': 203, 'min_data': 16, 'max_depth': 150}
# iteration number 45
# {'learning_rate': 0.643702977586379, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.17801630634986565, 'num_leaves': 134, 'min_data': 37, 'max_depth': 160} 9015
# failed with
# {'learning_rate': 0.643702977586379, 'boosting_type': 'dart', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.17801630634986565, 'num_leaves': 134, 'min_data': 37, 'max_depth': 160}
# iteration number 46
# {'learning_rate': 0.06814198313765274, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7671304954853231, 'num_leaves': 30, 'min_data': 65, 'max_depth': 110} 9201
# failed with
# {'learning_rate': 0.06814198313765274, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7671304954853231, 'num_leaves': 30, 'min_data': 65, 'max_depth': 110}
# iteration number 47
# {'learning_rate': 0.1333502580565803, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.12454751055785895, 'num_leaves': 231, 'min_data': 53, 'max_depth': 147} 5315
# failed with
# {'learning_rate': 0.1333502580565803, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.12454751055785895, 'num_leaves': 231, 'min_data': 53, 'max_depth': 147}
# iteration number 48
# {'learning_rate': 0.5493790588469559, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7460273570370333, 'num_leaves': 255, 'min_data': 11, 'max_depth': 84} 5305
# failed with
# {'learning_rate': 0.5493790588469559, 'boosting_type': 'gbdt', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.7460273570370333, 'num_leaves': 255, 'min_data': 11, 'max_depth': 84}
# iteration number 49
# {'learning_rate': 0.01446200298367839, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5811605152362583, 'num_leaves': 209, 'min_data': 14, 'max_depth': 163} 9162
# failed with
# {'learning_rate': 0.01446200298367839, 'boosting_type': 'goss', 'objective': 'regression', 'metric': 'mae', 'sub_feature': 0.5811605152362583, 'num_leaves': 209, 'min_data': 14, 'max_depth': 163}
# **************************************************
# Minimum is:  99999999999999999999999
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-6a916da5d391> in <module>()
#      32 print("*" * 50)
#      33 print('Minimum is: ', min)
# ---> 34 print('Used params', pp)
#
# NameError: name 'pp' is not defined
