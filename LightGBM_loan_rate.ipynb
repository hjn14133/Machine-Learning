# %% [markdown]
# <a href="https://colab.research.google.com/github/hjn14133/Machine-Learning/blob/main/LightGBM_loan_rate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Initial Setup
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt # data visualization
import seaborn as sns # statistical data visualization
from sklearn import metrics

# %%
# ignore warnings
import warnings
warnings.filterwarnings("ignore")

# %%
# Importing the dataset
df = pd.read_csv("FT_join_JH_cleaned.csv")

#Select columns
X = df[['DISTANCE', 'Heading','Elevation', 'AppliedRat']]
#y = df['VRYIELDBAL']
y = df['Loan_Rat']

# %%
# split the dataset into the training set and test set
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, 
                                                    random_state = 0)

# %%
# build the lightgbm model
import lightgbm as lgb
clf = lgb.LGBMRegressor()
clf.fit(X_train, y_train)
# Out:
# LGBMRegressor()

# %%
# predict the results
y_pred=clf.predict(X_test)

# %%
clf.get_params()
# Out:
# {'boosting_type': 'gbdt',
#  'class_weight': None,
#  'colsample_bytree': 1.0,
#  'importance_type': 'split',
#  'learning_rate': 0.1,
#  'max_depth': -1,
#  'min_child_samples': 20,
#  'min_child_weight': 0.001,
#  'min_split_gain': 0.0,
#  'n_estimators': 100,
#  'n_jobs': -1,
#  'num_leaves': 31,
#  'objective': None,
#  'random_state': None,
#  'reg_alpha': 0.0,
#  'reg_lambda': 0.0,
#  'silent': True,
#  'subsample': 1.0,
#  'subsample_for_bin': 200000,
#  'subsample_freq': 0}

# %%
print('Training Coefficient of R^2 : %.3f'%clf.score(X_train, y_train))
print('Test Coefficient of R^2 : %.3f'%clf.score(X_test, y_test))
# Out:
# Training Coefficient of R^2 : 0.565
# Test Coefficient of R^2 : 0.441

# %%
# Calculate the absolute errors
errors = abs(y_pred - y_test)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), '.')


# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / y_test)
# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 0.16 .
# Accuracy: 99.71 %.

# %%
# Print result of MAE
print(metrics.mean_absolute_error(y_test, y_pred))

# Print result of MSE
print(metrics.mean_squared_error(y_test, y_pred))

# Print result of RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, y_pred)))
# Out:
# 0.16206089108572394
# 0.04873767072862295
# 0.22076609959099913

# %%
# Get numerical feature importances
importances = list(clf.feature_importances_)
importances = importances/sum(importances)
feature_list = list(X.columns)
# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(feature_list, importances)]
# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)
# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: DISTANCE             Importance: 0.35
# Variable: Elevation            Importance: 0.24
# Variable: AppliedRat           Importance: 0.24
# Variable: Heading              Importance: 0.17

# %%
# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt
# %matplotlib inline
# Set the style
plt.style.use('fivethirtyeight')
# list of x locations for plotting
x_values = list(range(len(importances)))
# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')
# Tick labels for x axis
plt.xticks(x_values, feature_list, rotation='vertical')
# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# Plot actual data and predictions 

plt.figure(figsize=(10,10))
plt.scatter(y_pred, (y_test-y_pred), c='crimson')

#plt.plot([p1, p2], [p1, p2], 'b-')
plt.title('Cotton Loan Rate LightGBM Prediction vs Residuals', fontsize=15)
plt.xlabel('Cotton Loan Rate LightGBM Prediction', fontsize=15)
plt.ylabel('Residues', fontsize=15)
plt.show()

# %%
import time
start = time.time()
from sklearn.model_selection import RandomizedSearchCV
import lightgbm as lgb
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
lgb=lgb.LGBMRegressor(objective = 'regression')
parameters = {'num_leaves':[20,40,60,80,100], 
              'min_child_samples':[5,10,15],
              'learning_rate':[0.05,0.1,0.2],
              'reg_alpha':[0,0.01,0.03]}

clf=RandomizedSearchCV(lgb,parameters,scoring='r2',n_iter=100)
clf.fit(X=X_train, y=y_train)
print(clf.best_params_)
predicted=clf.predict(X_test)
print('MAE of Regression of the result is:')
print(mean_absolute_error(y_test, predicted))
end = time.time()
print('Execution time is:')
print(end - start)
# Out:
# {'reg_alpha': 0.03, 'num_leaves': 100, 'min_child_samples': 5, 'learning_rate': 0.05}
# MAE of Regression of the result is:
# 0.16004755752852257
# Execution time is:
# 109.72400999069214

# %%
print('Training Coefficient of R^2 : %.3f'%clf.score(X_train, y_train))
print('Test Coefficient of R^2 : %.3f'%clf.score(X_test, y_test))
# Out:
# Training Coefficient of R^2 : 0.678
# Test Coefficient of R^2 : 0.439

# %%
# Calculate the absolute errors
tune_errors = abs(predicted - y_test)
# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(tune_errors), 2), '.')


# Calculate mean absolute percentage error (MAPE)
tune_mape = 100 * (tune_errors / y_test)
# Calculate and display accuracy
tune_accuracy = 100 - np.mean(tune_mape)
print('Accuracy:', round(tune_accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 0.16 .
# Accuracy: 99.71 %.

# %%
# Print result of MAE
print(metrics.mean_absolute_error(y_test, predicted))

# Print result of MSE
print(metrics.mean_squared_error(y_test, predicted))

# Print result of RMSE
print(np.sqrt(metrics.mean_squared_error(y_test, predicted)))
# Out:
# 0.16004755752852257
# 0.04891482698523978
# 0.22116696630654356
